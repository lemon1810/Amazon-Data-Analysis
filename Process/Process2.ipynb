# %%
from google.colab import drive
drive.mount('gdrive')
# Out:
# Drive already mounted at gdrive; to attempt to forcibly remount, call drive.mount("gdrive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Import Data

# %%
path= "/content/gdrive/MyDrive/IE224/Process1/process1_output.csv"

# %%
df= pd.read_csv(path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1415 non-null   object
#  1   TypeName           1380 non-null   object
#  2   Inches             1274 non-null   float64
#  3   ScreenResolution   1239 non-null   object
#  4   Cpu                1238 non-null   object
#  5   Ram                1412 non-null   object
#  6   Memory             1379 non-null   object
#  7   Gpu                1392 non-null   object
#  8   OpSys              1417 non-null   object
#  9   Weight             1243 non-null   float64
#  10  Price              1357 non-null   float64
#  11  Ram_capacity       1412 non-null   float64
#  12  Ram_model          162 non-null    object
#  13  Touchscreen        1417 non-null   int64
#  14  Screen_resolution  1239 non-null   object
#  15  Brand_RAM          1238 non-null   object
# ...

# %%
df
# Out:
#         Company  TypeName  Inches                 ScreenResolution  \
# 0        Lenovo  Notebook    17.3                Full HD 1920x1080
# 1            HP  Notebook    17.3      IPS Panel Full HD 1920x1080
# 2          Acer  Notebook    17.3                         1366x768
# 3            HP  Notebook    15.6      IPS Panel Full HD 1920x1080
# 4            HP  Notebook    17.3      IPS Panel Full HD 1920x1080
# ...         ...       ...     ...                              ...
# 1412       Dell       NaN     NaN                              NaN
# 1413         HP       NaN     NaN                              NaN
# 1414         HP       NaN     NaN                              NaN
# 1415  Alienware       NaN     NaN                              NaN
# 1416    Samsung  Notebook    15.6  IPS Panel Touchscreen 2400x1600
#
#                                   Cpu         Ram     Memory  \
# 0         AMD A10-Series 9600P 2.4GHz         6GB  128GB HDD
# ...

# %% [markdown]
# #Kiểm tra các giá trị Mode của Company và điền khuyết

# %%
df['Company'].mode()
# Out:
# 0    Dell
# Name: Company, dtype: object

# %%
df['Company']=df['Company'].replace(to_replace=np.nan, value='Dell')

# %%
df['Company'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #Kiểm tra các giá trị Mode của Typename và điền khuyết

# %%
df['TypeName'].mode()
# Out:
# 0    Notebook
# Name: TypeName, dtype: object

# %%
df['TypeName']=df['TypeName'].replace(to_replace=np.nan, value='Notebook')

# %%
df['TypeName'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #Kiểm tra các giá trị mode, median, mean của Inches và điền khuyết

# %%
print('Mode:', df['Inches'].mode(), '\n', 'Median', df['Inches'].median(), '\n', 'Mean', df['Inches'].mean())
# Out:
# Mode: 0    17.3
# Name: Inches, dtype: float64
#  Median 17.3
#  Mean 16.299372056514915

# %%
df['Inches']=df['Inches'].replace(to_replace=np.nan, value=df['Inches'].median())

# %%
df['Inches'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #Kiểm tra các giá trị Mode của OpSys và điền khuyết

# %%
df['OpSys'].mode()
# Out:
# 0    Windows 10
# Name: OpSys, dtype: object

# %%
df['OpSys']=df['OpSys'].replace(to_replace=np.nan, value='Windows 10')

# %%
df['OpSys'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #Kiểm tra các giá trị mode, median, mean của Weight và điền khuyết

# %%
print('Mode:', df['Weight'].mode(), '\n', 'Median', df['Weight'].median(), '\n', 'Mean', df['Weight'].mean())
# Out:
# Mode: 0    2.2
# Name: Weight, dtype: float64
#  Median 2.04
#  Mean 2.030836685438455

# %%
df['Weight']=df['Weight'].replace(to_replace=np.nan, value=df['Weight'].median())

# %%
df['Weight'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #Kiểm tra các giá trị mode, median, mean của Ram_capacity và điền khuyết

# %%
print('Mode:', df['Ram_capacity'].mode(), '\n', 'Median', df['Ram_capacity'].median(), '\n', 'Mean', df['Ram_capacity'].mean())
# Out:
# Mode: 0    8.0
# Name: Ram_capacity, dtype: float64
#  Median 8.0
#  Mean 28.957507082152976

# %%
df['Ram_capacity']=df['Ram_capacity'].replace(to_replace=np.nan, value=df['Ram_capacity'].median())

# %%
df['Ram_capacity'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #Kiểm tra các giá trị BIN của Ram_model và điền khuyết

# %%
df['Ram_model'] = df['Ram_model'].notnull().astype(int)

# %%
df['Ram_model'].value_counts()
# Out:
# 0    1255
# 1     162
# Name: Ram_model, dtype: int64

# %% [markdown]
# #Kiểm tra các giá trị mode của Screen_resolution và điền khuyết

# %%
df['Screen_resolution'].mode()
# Out:
# 0    1920x1080
# Name: Screen_resolution, dtype: object

# %%
df['Screen_resolution']=df['Screen_resolution'].replace(to_replace=np.nan, value='1920x1080')

# %% [markdown]
# #Kiểm tra các giá trị mode của Brand_RAM và điền khuyết

# %%
df['Brand_RAM'].mode()
# Out:
# 0    Intel
# Name: Brand_RAM, dtype: object

# %%
df['Brand_RAM']=df['Brand_RAM'].replace(to_replace=np.nan, value='Intel')

# %% [markdown]
# ##Kiểm tra các giá trị mode, median, mean của Model và điền khuyết

# %%
df['Model'].mode()
# Out:
# 0    Core i5 7200U
# Name: Model, dtype: object

# %%
df['Model']=df['Model'].replace(to_replace=np.nan, value='Core i5 7200U')

# %% [markdown]
# # Kiểm tra giá trị mode, median, mean của Clockspeed và điền khuyết

# %%
print('Mode:', df['Clockspeed'].mode(), '\n', 'Median', df['Clockspeed'].median(), '\n', 'Mean', df['Clockspeed'].mean())
# Out:
# Mode: 0    2.5
# Name: Clockspeed, dtype: float64
#  Median 2.5
#  Mean 2.303877221324717

# %%
df['Clockspeed']=df['Clockspeed'].replace(to_replace=np.nan, value=df['Clockspeed'].median())

# %%
df['Clockspeed'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #Kiểm tra giá trị mode của Memory1 và điền khuyết

# %%
df['Memory1'].mode()
# Out:
# 0    128GB HDD
# Name: Memory1, dtype: object

# %%
df['Memory1']=df['Memory1'].replace(to_replace=np.nan, value='256GB SSD')

# %% [markdown]
# # Kiểm tra giá trị và điền khuyết Memory 2

# %%
df['Memory2'] = df['Memory2'].notnull().astype(int)

# %% [markdown]
# #Kiểm tra giá trị mode, median, mean của Capacity1 và điền khuyết

# %%
print('Mode:', df['Capacity1'].mode(), '\n', 'Median', df['Capacity1'].median(), '\n', 'Mean', df['Capacity1'].mean())
# Out:
# Mode: 0    128.0
# Name: Capacity1, dtype: float64
#  Median 256.0
#  Mean 407.0210297316896

# %%
df['Capacity1']=df['Capacity1'].replace(to_replace=np.nan, value=df['Capacity1'].median())

# %% [markdown]
# # Kiểm tra giá trị mode và điền khuyết Storage_Type_1

# %%
df['Storage_Type_1'].mode()
# Out:
# 0    SSD
# Name: Storage_Type_1, dtype: object

# %%
df['Storage_Type_1']=df['Storage_Type_1'].replace(to_replace=np.nan, value='SSD')

# %% [markdown]
# #Kiểm tra giá trị mode, median, mean của Capacity2 và điền khuyết

# %%
df['Capacity2'].value_counts()
# Out:
# 1000.0    264
# 512.0      55
# 2000.0      1
# 256.0       1
# Name: Capacity2, dtype: int64

# %%
df['Capacity2']=df['Capacity2'].replace(1, 1000)
df['Capacity2']=df['Capacity2'].fillna(0)

# %%
df['Capacity2'].value_counts()
# Out:
# 0.0       1096
# 1000.0     264
# 512.0       55
# 2000.0       1
# 256.0        1
# Name: Capacity2, dtype: int64

# %% [markdown]
# # Kiểm tra giá trị mode và điền khuyết Storage_Type_2

# %%
df['Storage_Type_2'] = df['Storage_Type_2'].notnull().astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1417 entries, 0 to 1416
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1417 non-null   object
#  1   TypeName           1417 non-null   object
#  2   Inches             1417 non-null   float64
#  3   ScreenResolution   1239 non-null   object
#  4   Cpu                1238 non-null   object
#  5   Ram                1412 non-null   object
#  6   Memory             1379 non-null   object
#  7   Gpu                1392 non-null   object
#  8   OpSys              1417 non-null   object
#  9   Weight             1417 non-null   float64
#  10  Price              1357 non-null   float64
#  11  Ram_capacity       1417 non-null   float64
#  12  Ram_model          1417 non-null   int64
#  13  Touchscreen        1417 non-null   int64
#  14  Screen_resolution  1417 non-null   object
#  15  Brand_RAM          1417 non-null   object
# ...

# %%
df = df.dropna(subset=['Price'])

# %%
df.dropna(subset=['Price'], inplace=True)
# Out:
# <ipython-input-107-31f9b937c3c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['Price'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1357 entries, 0 to 1416
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1357 non-null   object
#  1   TypeName           1357 non-null   object
#  2   Inches             1357 non-null   float64
#  3   ScreenResolution   1239 non-null   object
#  4   Cpu                1238 non-null   object
#  5   Ram                1353 non-null   object
#  6   Memory             1344 non-null   object
#  7   Gpu                1346 non-null   object
#  8   OpSys              1357 non-null   object
#  9   Weight             1357 non-null   float64
#  10  Price              1357 non-null   float64
#  11  Ram_capacity       1357 non-null   float64
#  12  Ram_model          1357 non-null   int64
#  13  Touchscreen        1357 non-null   int64
#  14  Screen_resolution  1357 non-null   object
#  15  Brand_RAM          1357 non-null   object
# ...

# %% [markdown]
# #Encoded các giá trị đặc biệt ScreenResolutio, Cpu , Memory,  Gpu

# %%
from sklearn.preprocessing import LabelEncoder

# Tạo một đối tượng LabelEncoder
label_encoder = LabelEncoder()

# Áp dụng LabelEncoder cho cột 'ScreenResolution'
df['ScreenResolution_encoded'] = label_encoder.fit_transform(df['ScreenResolution'])
# Out:
# <ipython-input-109-a510c057af03>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ScreenResolution_encoded'] = label_encoder.fit_transform(df['ScreenResolution'])

# %%
df['Cpu_encoded'] = label_encoder.fit_transform(df['Cpu'])
# Out:
# <ipython-input-110-edb6b1d7f30a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu_encoded'] = label_encoder.fit_transform(df['Cpu'])

# %%
df['Gpu_encoded'] = label_encoder.fit_transform(df['Gpu'])
# Out:
# <ipython-input-111-d559eed53b60>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gpu_encoded'] = label_encoder.fit_transform(df['Gpu'])

# %%
df['Memory_encoded'] = label_encoder.fit_transform(df['Memory'])
# Out:
# <ipython-input-112-a2808a3aa88f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory_encoded'] = label_encoder.fit_transform(df['Memory'])

# %%
df.isnull().sum()
# Out:
# Company                       0
# TypeName                      0
# Inches                        0
# ScreenResolution            118
# Cpu                         119
# Ram                           4
# Memory                       13
# Gpu                          11
# OpSys                         0
# Weight                        0
# Price                         0
# Ram_capacity                  0
# Ram_model                     0
# Touchscreen                   0
# Screen_resolution             0
# Brand_RAM                     0
# Model                         0
# Clockspeed                    0
# Memory1                       0
# Memory2                       0
# Capacity1                     0
# Storage_Type_1                0
# Capacity2                     0
# Storage_Type_2                0
# ScreenResolution_encoded      0
# Cpu_encoded                   0
# Gpu_encoded                   0
# Memory_encoded                0
# dtype: int64

# %% [markdown]
# #Export to CSV and Excel

# %%
df = df.drop(columns=['ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu'])

# %%
save = "/content/gdrive/MyDrive/IE224/Process 2/"

# Save as CSV
df.to_csv(save + 'data_process2.csv', index=False)

# Save as Excel
df.to_excel(save + 'data_process2.xlsx', index=False)
